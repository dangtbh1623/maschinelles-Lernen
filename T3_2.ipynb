# %% [markdown]
# # Übung 3
# ## Aufgabe T3.2

# %% [markdown]
#  **Benötigte Biliotheken importieren

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Daten erstellen

# %%
data=np.array([[1,1],[2,2],[3,3],[1,5],[5,4],])
labelList = ['A','B','C','D','E']

# %% [markdown]
# **Verwendet Clustering-Ansatz Single-Linkage mit der Minkowski Metrik p=1

# %%
linked = linkage(data, 'single', metric='cityblock')

# %% [markdown]
# **Zeichne Dendrogramm

# %%
plt.figure(figsize=(10, 7))
plt.title('Clustering Dendrogram')
plt.xlabel('Species')
plt.ylabel('Distance')
dendrogram(linked,
          labels=labelList,
           distance_sort='descending',
            show_leaf_counts=True)
plt.show()

# %% [markdown]
# **Zeichne der Bereich, in dem man 3 Cluster erhalten kann

# %%
plt.figure(figsize=(10, 7))
plt.title('Clustering Dendrogram')
plt.xlabel('Species')
plt.ylabel('Distance')
dendrogram(linked,
          labels=labelList,
           distance_sort='descending',
            show_leaf_counts=True)
plt.axhline(y=2.5, c='red')
plt.show()
