# %% [markdown]
# # Aufgabe S3_2

# %% [markdown]
# **Laden Iris-Datensatz

# %%
from sklearn import datasets
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
iris = datasets.load_iris()
X=iris.data[1::3,:]
Y=iris.target[1::3]

# %% [markdown]
# **Die Blumen zu Cluster einordnen. Bei DEFAULT werden die Methode "Single" und Distanzmaß "euclidean" eingestellt.
# Mit der "method=" und "metric=" kann man verschiedenen Einstellungen verwenden.

# %%
linked = linkage(X, method='ward',metric='euclidean')

# %% [markdown]
# **Plotten

# %%
plt.figure(figsize=(20, 10))
plt.title('Iris Hierarchical Clustering Dendrogram')
plt.xlabel('Species')
plt.ylabel('Distance')
dendrogram(linked, labels=Y, leaf_rotation=0., leaf_font_size=16., distance_sort='descending' )
plt.show()
